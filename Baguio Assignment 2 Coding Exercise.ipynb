# %% [markdown]
# # Name: Christian Jay Baguio
# # Section: DS1A

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
tds_df = pd.read_csv("titanic_dataset.csv")
tds_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## A Bar chart(using matplotlib)

# %%
tds_df = pd.read_csv("titanic_dataset.csv")
tds_df = tds_df.sort_values(by="PassengerId")

#calling two specific column to use for chart
tds_df1 = tds_df.values
x_1 = tds_df1[:,0]
y_1 = tds_df1[:,5]

#creating a figure by using plotlib
fig_1 = plt.figure(figsize = (8, 6))
axes_1 = fig_1.add_axes([2,2,2,1])

#setting a title for the bar chart
axes_1.set_title("Age range or each Passenger")

#since the ammount of passenger is huge lets just zoom the axes range from 0 to 200
axes_1.set_xlim([0,200])
axes_1.set_ylim([0,80])
axes_1.set_xlabel("PassengerId")
axes_1.set_ylabel("Age")
axes_1.bar(x_1, y_1, label = "Each bar line indicates one person\n"
           "Blank line gaps indicate of no age info")
axes_1.legend(loc=0)

# %% [markdown]
# ## if need to see all age range info run the code below

# %%
_1 = tds_df1[:,0]
y_1 = tds_df1[:,5]

fig_2 = plt.figure(figsize = (8, 6))
axes_2 = fig_2.add_axes([2,2,2,1])

axes_2.set_title("Age range of all 891 Passengers")
axes_2.set_xlabel("PassengerId")
axes_2.set_ylabel("Age")

axes_2.bar(x_1, y_1, label = "Each bar line indicates one person\n"
           "Blank line gaps indicate of no age info")
axes_2.legend(loc=0)

#create annotate to give info of who is the oldest person on board
axes_2.annotate("Oldest person on board", xy = (635, 80), xytext = (450, 75),
                arrowprops = dict(facecolor = "red", shrink = 0.05))
# Out:
# Text(450, 75, 'Oldest person on board')

# %% [markdown]
# # A Pie graph(matplotlib)

# %%
#wla na talaga sir give up nako ani nga graph T.T
x_1 = tds_df["PassengerId"]
y_1 = tds_df["Embarked"]

#fig_1 = plt.figure(figsize = (8, 5))
#axes_1 = fig_1.add_axes([2,2,2,1])

#setting a title for the bar chart
#axes_1.set_title("Fare range")

plt.pie(x_1, labels = y_1)
# Out:
# ([<matplotlib.patches.Wedge at 0x211f055d6d0>,
# ...
#  [Text(1.0999999999656256, 8.696209517655881e-06, 'S'),
#   Text(1.099999999450007, 3.4784838065188465e-05, 'C'),
#   Text(1.0999999972156596, 7.826588559368217e-05, 'S'),
#   Text(1.0999999912001095, 0.00013913935191290982, 'S'),
#   Text(1.0999999785158918, 0.00021740523809977457, 'S'),
#   Text(1.0999999554505533, 0.0003130635415555555, 'Q'),
#   Text(1.0999999174666502, 0.0004261142604268957, 'S'),
#   Text(1.0999998592017501, 0.0005565573916755952, 'S'),
#   Text(1.0999997744684331, 0.0007043929275116871, 'S'),
#   Text(1.0999996562542858, 0.0008696208674762337, 'C'),
#   Text(1.0999994967219087, 0.0010522412021720107, 'S'),
#   Text(1.0999992872089228, 0.001252253912643914, 'S'),
#   Text(1.0999990182279518, 0.0014696589885520625, 'S'),
#   Text(1.0999986794666399, 0.001704456408563839, 'S'),
#   Text(1.099998259787662, 0.0019566461395386417, 'S'),
#   Text(1.099997747228708, 0.002226228148219349, 'S'),
# ...

# %% [markdown]
# # A Violin Plot(using seaborn

# %%
sns.set_theme(style="whitegrid")

sns.violinplot(data = tds_df, x = "Sex", y = "Age", hue = "Survived", split = True)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %%
sns.set_theme(style = "whitegrid")

sns.violinplot(data = tds_df, x = "Pclass", y = "Age", hue = "Sex")
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# # A scatter plot (using seaborn)

# %%
sns.set_theme(style="whitegrid")

sns.scatterplot(data = tds_df, x = "PassengerId", y = "Fare", hue = "Pclass",
               palette = ["black", "yellow", "grey"],
               sizes = [200, 800000])
# Out:
# <AxesSubplot:xlabel='PassengerId', ylabel='Fare'>

# %%
sns.set_theme(style="whitegrid")

fig_6 = plt.figure(figsize = (8, 6))
axes_6 = fig_6.add_axes([2,2,2,1])

axes_6 = sns.scatterplot(data = tds_df, x = "PassengerId", y = "Age", hue = "Embarked")

# %% [markdown]
# # A wordcloud(using matplotlib)

# %%
stopwords = set(STOPWORDS)

def Wordcloud(data, title = None):
    wordcloud = WordCloud(
        background_color = "White",
        stopwords = stopwords,
        max_words = 150,
        max_font_size = 40,
        scale = 3,
        ).generate(str(data))
    
    fig = plt.figure(1, figsize = (20, 20))
    plt.axis("off")
    if title:
        fig.suptitle(title, fontsize = 20)
        fig.subplots_adjust(top = 2.3)
    plt.imshow(wordcloud)
    
Wordcloud(tds_df["Name"].dropna())
